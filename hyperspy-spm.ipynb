# %%
# %matplotlib nbagg 

import hyperspy.api as hs 

import pySPM

# %%
scan = pySPM.Bruker('minicircle.spm')

# %%
topo_forward = scan.get_channel()

# %%
img = hs.signals.Signal2D(topo_forward.pixels)

# %%
img.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
